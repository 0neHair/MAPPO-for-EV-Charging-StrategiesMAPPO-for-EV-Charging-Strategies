# %%
import torch
# import torch._dynamo
# torch._dynamo.config.suppress_errors = True

def foo(x, y):
    a = torch.sin(x)
    b = torch.cos(x)
    return a + b
opt_foo1 = torch.compile(foo)
print(opt_foo1(torch.randn(10, 10), torch.randn(10, 10)))
# Out:
# ---------------------------------------------------------------------------
# BackendCompilerFailed                     Traceback (most recent call last)
# Cell In[1], line 10
#       8     return a + b
#       9 opt_foo1 = torch.compile(foo)
# ---> 10 print(opt_foo1(torch.randn(10, 10), torch.randn(10, 10)))
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\eval_frame.py:451, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     449 prior = set_eval_frame(callback)
#     450 try:
# --> 451     return fn(*args, **kwargs)
#     452 finally:
#     453     set_eval_frame(prior)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\convert_frame.py:921, in catch_errors_wrapper.<locals>.catch_errors(frame, cache_entry, frame_state)
#     917             return hijacked_callback(frame, cache_entry, hooks, frame_state)
#     919 with compile_lock, _disable_current_modes():
#     920     # skip=1: skip this frame
# --> 921     return callback(frame, cache_entry, hooks, frame_state, skip=1)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\convert_frame.py:786, in convert_frame.<locals>._convert_frame(frame, cache_entry, hooks, frame_state, skip)
#     784 counters["frames"]["total"] += 1
#     785 try:
# --> 786     result = inner_convert(
#     787         frame, cache_entry, hooks, frame_state, skip=skip + 1
#     788     )
#     789     counters["frames"]["ok"] += 1
#     790     return result
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\convert_frame.py:400, in convert_frame_assert.<locals>._convert_frame_assert(frame, cache_entry, hooks, frame_state, skip)
#     386 compile_id = CompileId(frame_id, frame_compile_id)
#     388 signpost_event(
#     389     "dynamo",
#     390     "_convert_frame_assert._compile",
#    (...)
#     397     },
#     398 )
# --> 400 return _compile(
#     401     frame.f_code,
#     402     frame.f_globals,
#     403     frame.f_locals,
#     404     frame.f_builtins,
#     405     compiler_fn,
#     406     one_graph,
#     407     export,
#     408     export_constraints,
#     409     hooks,
#     410     cache_size,
#     411     frame,
#     412     frame_state=frame_state,
#     413     compile_id=compile_id,
#     414     skip=skip + 1,
#     415 )
#
# File c:\Users\10199\Python\3.11\Lib\contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\convert_frame.py:676, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_size, frame, frame_state, compile_id, skip)
#     674 fail_user_frame_lineno: Optional[int] = None
#     675 try:
# --> 676     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     677     return guarded_code
#     678 except (
#     679     Unsupported,
#     680     TorchRuntimeError,
#    (...)
#     687     BisectValidationException,
#     688 ) as e:
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\utils.py:262, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     260 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     261     t0 = time.time()
# --> 262     r = func(*args, **kwargs)
#     263     time_spent = time.time() - t0
#     264 compilation_time_metrics[key].append(time_spent)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\convert_frame.py:535, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     533 CompileContext.get().attempt = attempt
#     534 try:
# --> 535     out_code = transform_code_object(code, transform)
#     536     break
#     537 except exc.RestartAnalysis as e:
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\bytecode_transformation.py:1036, in transform_code_object(code, transformations, safe)
#    1033 instructions = cleaned_instructions(code, safe)
#    1034 propagate_line_nums(instructions)
# -> 1036 transformations(instructions, code_options)
#    1037 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\convert_frame.py:165, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     163 cleanup = setup_compile_debug()
#     164 try:
# --> 165     return fn(*args, **kwargs)
#     166 finally:
#     167     cleanup.close()
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\convert_frame.py:500, in _compile.<locals>.transform(instructions, code_options)
#     498 try:
#     499     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 500         tracer.run()
#     501 except exc.UnspecializeRestartAnalysis:
#     502     speculation_log.clear()
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\symbolic_convert.py:2149, in InstructionTranslator.run(self)
#    2148 def run(self):
# -> 2149     super().run()
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\symbolic_convert.py:810, in InstructionTranslatorBase.run(self)
#     805 try:
#     806     self.output.push_tx(self)
#     807     while (
#     808         self.instruction_pointer is not None
#     809         and not self.output.should_exit
# --> 810         and self.step()
#     811     ):
#     812         pass
#     813 except BackendCompilerFailed:
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\symbolic_convert.py:773, in InstructionTranslatorBase.step(self)
#     769         unimplemented(f"missing: {inst.opname}")
#     770     TracingContext.set_current_loc(
#     771         self.f_code.co_filename, self.lineno, self.f_code.co_name
#     772     )
# --> 773     getattr(self, inst.opname)(inst)
#     775     return inst.opname != "RETURN_VALUE"
#     776 except Unsupported:
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\symbolic_convert.py:2268, in InstructionTranslator.RETURN_VALUE(self, inst)
#    2263 _step_logger()(
#    2264     logging.INFO,
#    2265     f"torchdynamo done tracing {self.f_code.co_name} (RETURN_VALUE)",
#    2266 )
#    2267 log.debug("RETURN_VALUE triggered compile")
# -> 2268 self.output.compile_subgraph(
#    2269     self,
#    2270     reason=GraphCompileReason(
#    2271         "return_value", [self.frame_summary()], graph_break=False
#    2272     ),
#    2273 )
#    2274 self.output.add_output_instructions([create_instruction("RETURN_VALUE")])
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\output_graph.py:971, in OutputGraph.compile_subgraph(self, tx, partial_convert, reason)
#     968     append_prefix_insts()
#     969     # optimization to generate better code in a common case
#     970     self.add_output_instructions(
# --> 971         self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
#     972         + [create_instruction("UNPACK_SEQUENCE", arg=len(stack_values))]
#     973     )
#     974 else:
#     975     graph_output_var = self.new_var("graph_out")
#
# File c:\Users\10199\Python\3.11\Lib\contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\output_graph.py:1168, in OutputGraph.compile_and_call_fx_graph(self, tx, rv, root)
#    1165     self.tracing_context.fake_mode = backend_fake_mode
#    1167 with self.restore_global_state():
# -> 1168     compiled_fn = self.call_user_compiler(gm)
#    1169 compiled_fn = disable(compiled_fn)
#    1171 counters["stats"]["unique_graphs"] += 1
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\utils.py:262, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     260 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     261     t0 = time.time()
# --> 262     r = func(*args, **kwargs)
#     263     time_spent = time.time() - t0
#     264 compilation_time_metrics[key].append(time_spent)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\output_graph.py:1241, in OutputGraph.call_user_compiler(self, gm)
#    1239     raise e
#    1240 except Exception as e:
# -> 1241     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
#    1242         e.__traceback__
#    1243     ) from None
#    1245 signpost_event(
#    1246     "dynamo",
#    1247     "OutputGraph.call_user_compiler",
#    (...)
#    1253     },
#    1254 )
#    1256 return compiled_fn
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\output_graph.py:1222, in OutputGraph.call_user_compiler(self, gm)
#    1220 if config.verify_correctness:
#    1221     compiler_fn = WrapperBackend(compiler_fn)
# -> 1222 compiled_fn = compiler_fn(gm, self.example_inputs())
#    1223 _step_logger()(logging.INFO, f"done compiler function {name}")
#    1224 assert callable(compiled_fn), "compiler_fn did not return callable"
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py:117, in wrap_backend_debug.<locals>.debug_wrapper(gm, example_inputs, **kwargs)
#     115             raise
#     116 else:
# --> 117     compiled_gm = compiler_fn(gm, example_inputs)
#     119 return compiled_gm
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\__init__.py:1729, in _TorchCompileInductorWrapper.__call__(self, model_, inputs_)
#    1726 def __call__(self, model_, inputs_):
#    1727     from torch._inductor.compile_fx import compile_fx
# -> 1729     return compile_fx(model_, inputs_, config_patches=self.config)
#
# File c:\Users\10199\Python\3.11\Lib\contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\compile_fx.py:1330, in compile_fx(model_, example_inputs_, inner_compile, config_patches, decompositions)
#    1325         return inference_compiler(unlifted_gm, example_inputs_)
#    1327 with V.set_fake_mode(fake_mode), torch._guards.tracing(
#    1328     tracing_context
#    1329 ), compiled_autograd.disable():
# -> 1330     return aot_autograd(
#    1331         fw_compiler=fw_compiler,
#    1332         bw_compiler=bw_compiler,
#    1333         inference_compiler=inference_compiler,
#    1334         decompositions=decompositions,
#    1335         partition_fn=partition_fn,
#    1336         keep_inference_input_mutations=True,
#    1337     )(model_, example_inputs_)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\backends\common.py:58, in aot_autograd.<locals>.compiler_fn(gm, example_inputs)
#      55 try:
#      56     # NB: NOT cloned!
#      57     with enable_aot_logging(), patch_config:
# ---> 58         cg = aot_module_simplified(gm, example_inputs, **kwargs)
#      59         counters["aot_autograd"]["ok"] += 1
#      60         return disable(cg)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_functorch\aot_autograd.py:903, in aot_module_simplified(mod, args, fw_compiler, bw_compiler, partition_fn, decompositions, keep_inference_input_mutations, inference_compiler)
#     887 aot_config = AOTConfig(
#     888     fw_compiler=fw_compiler,
#     889     bw_compiler=bw_compiler,
#    (...)
#     899     no_tangents=False,
#     900 )
#     902 with compiled_autograd.disable():
# --> 903     compiled_fn = create_aot_dispatcher_function(
#     904         functional_call,
#     905         full_args,
#     906         aot_config,
#     907     )
#     909 # TODO: There is something deeply wrong here; compiled_fn running with
#     910 # the boxed calling convention, but aot_module_simplified somehow
#     911 # historically returned a function that was not the boxed calling
#     912 # convention.  This should get fixed...
#     913 def forward(*runtime_args):
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\utils.py:262, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     260 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     261     t0 = time.time()
# --> 262     r = func(*args, **kwargs)
#     263     time_spent = time.time() - t0
#     264 compilation_time_metrics[key].append(time_spent)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_functorch\aot_autograd.py:628, in create_aot_dispatcher_function(flat_fn, flat_args, aot_config)
#     625 compiler_fn = partial(aot_wrapper_dedupe, compiler_fn=compiler_fn)
#     626 # You can put more passes here
# --> 628 compiled_fn = compiler_fn(flat_fn, fake_flat_args, aot_config, fw_metadata=fw_metadata)
#     629 if aot_config.is_export:
#     630     # During export, we don't get back a callable - we get back the raw fx graph
#     631     # (either a joint or an inference-only graph)
#     632     assert isinstance(compiled_fn, torch.fx.GraphModule)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_functorch\_aot_autograd\runtime_wrappers.py:443, in aot_wrapper_dedupe(flat_fn, flat_args, aot_config, compiler_fn, fw_metadata)
#     440             break
#     442     if ok:
# --> 443         return compiler_fn(flat_fn, leaf_flat_args, aot_config, fw_metadata=fw_metadata)
#     445     if requires_subclass_dispatch(leaf_flat_args, fw_metadata):
#     446         raise RuntimeError(
#     447             """\
#     448 Encountered duplicate inputs that are mutated in the graph, but at least one input/output
#     449 to the graph is a tensor subclass. This is not supported today. You can try to
#     450 remove the aliasing yourself as a workaround, or otherwise file an issue on github."""
#     451         )
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_functorch\_aot_autograd\runtime_wrappers.py:648, in aot_wrapper_synthetic_base(flat_fn, flat_args, aot_config, fw_metadata, needs_autograd, compiler_fn)
#     646 # Happy path: we don't need synthetic bases
#     647 if synthetic_base_info is None:
# --> 648     return compiler_fn(flat_fn, flat_args, aot_config, fw_metadata=fw_metadata)
#     650 # export path: ban synthetic bases for now, add later if requested.
#     651 if requires_subclass_dispatch(flat_args, fw_metadata):
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py:119, in aot_dispatch_base(flat_fn, flat_args, aot_config, fw_metadata)
#     112     tracing_context.fw_metadata = (
#     113         fw_metadata
#     114         if maybe_subclass_meta is None
#     115         else maybe_subclass_meta.fw_metadata
#     116     )
#     118 with TracingContext.report_output_strides() as fwd_output_strides:
# --> 119     compiled_fw = compiler(fw_module, updated_flat_args)
#     121 # see note: [Returning Fake Tensors on First AOT Autograd Call]
#     122 if tracing_context and tracing_context.fakify_first_call:
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\utils.py:262, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     260 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     261     t0 = time.time()
# --> 262     r = func(*args, **kwargs)
#     263     time_spent = time.time() - t0
#     264 compilation_time_metrics[key].append(time_spent)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\compile_fx.py:1257, in compile_fx.<locals>.fw_compiler_base(model, example_inputs, is_inference)
#    1249     assert orig_output_end_idx <= num_model_outputs
#    1251     user_visible_outputs = {
#    1252         n.name
#    1253         for n in model_outputs[original_output_start_index:orig_output_end_idx]
#    1254         if isinstance(n, torch.fx.Node)
#    1255     }
# -> 1257 return inner_compile(
#    1258     model,
#    1259     example_inputs,
#    1260     num_fixed=fixed,
#    1261     cudagraphs=cudagraphs,
#    1262     graph_id=graph_id,
#    1263     is_inference=is_inference,
#    1264     boxed_forward_device_index=forward_device,
#    1265     user_visible_outputs=user_visible_outputs,
#    1266 )
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\repro\after_aot.py:83, in wrap_compiler_debug.<locals>.debug_wrapper(gm, example_inputs, **kwargs)
#      78 assert config.repro_after in ("dynamo", "aot", None)
#      80 try:
#      81     # Call the compiler_fn - which is either aot_autograd or inductor
#      82     # with fake inputs
# ---> 83     inner_compiled_fn = compiler_fn(gm, example_inputs)
#      84 except Exception as e:
#      85     # TODO: Failures here are troublesome because no real inputs,
#      86     # need a different serialization strategy
#      87     if config.repro_after == "aot":
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\debug.py:304, in DebugContext.wrap.<locals>.inner(*args, **kwargs)
#     301 @functools.wraps(fn)
#     302 def inner(*args, **kwargs):
#     303     with DebugContext():
# --> 304         return fn(*args, **kwargs)
#
# File c:\Users\10199\Python\3.11\Lib\contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File c:\Users\10199\Python\3.11\Lib\contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\utils.py:262, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     260 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     261     t0 = time.time()
# --> 262     r = func(*args, **kwargs)
#     263     time_spent = time.time() - t0
#     264 compilation_time_metrics[key].append(time_spent)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\compile_fx.py:438, in compile_fx_inner(gm, example_inputs, cudagraphs, num_fixed, is_backward, graph_id, cpp_wrapper, aot_mode, is_inference, boxed_forward_device_index, user_visible_outputs, layout_opt, extern_node_serializer)
#     434     compiled_graph = FxGraphCache.load(
#     435         fx_codegen_and_compile, gm, example_inputs, graph_kwargs
#     436     )
#     437 else:
# --> 438     compiled_graph = fx_codegen_and_compile(
#     439         gm, example_inputs, **graph_kwargs  # type: ignore[arg-type]
#     440     )
#     442 log.debug("FX codegen and compilation took %.3fs", time.time() - start)
#     444 # check cudagraph disabling reasons from inductor lowering
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\compile_fx.py:714, in fx_codegen_and_compile(gm, example_inputs, cudagraphs, num_fixed, is_backward, graph_id, cpp_wrapper, aot_mode, is_inference, user_visible_outputs, layout_opt, extern_node_serializer)
#     711             output_strides.append(None)
#     713 metrics_helper = metrics.CachedMetricsHelper()
# --> 714 compiled_fn = graph.compile_to_fn()
#     716 if V.aot_compilation is True:
#     717     return compiled_fn
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\graph.py:1307, in GraphLowering.compile_to_fn(self)
#    1303     return AotCodeCompiler.compile(
#    1304         self, code, serialized_extern_kernel_nodes, cuda=self.cuda
#    1305     )
#    1306 else:
# -> 1307     return self.compile_to_module().call
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\utils.py:262, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     260 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     261     t0 = time.time()
# --> 262     r = func(*args, **kwargs)
#     263     time_spent = time.time() - t0
#     264 compilation_time_metrics[key].append(time_spent)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\graph.py:1250, in GraphLowering.compile_to_module(self)
#    1245 @dynamo_timed(phase_name="code_gen")
#    1246 def compile_to_module(self):
#    1247     from .codecache import PyCodeCache
#    1249     code, linemap = (
# -> 1250         self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
#    1251     )
#    1252     linemap = [(line_no, node.stack_trace) for line_no, node in linemap]
#    1253     key, path = PyCodeCache.write(code)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\graph.py:1208, in GraphLowering.codegen(self)
#    1205 self.scheduler = Scheduler(self.buffers)
#    1206 V.debug.draw_orig_fx_graph(self.orig_gm, self.scheduler.nodes)
# -> 1208 self.scheduler.codegen()
#    1209 return self.wrapper_code.generate(self.is_inference)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_dynamo\utils.py:262, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     260 with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     261     t0 = time.time()
# --> 262     r = func(*args, **kwargs)
#     263     time_spent = time.time() - t0
#     264 compilation_time_metrics[key].append(time_spent)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\scheduler.py:2339, in Scheduler.codegen(self)
#    2337     self.get_backend(device).codegen_foreach(node)  # type: ignore[possibly-undefined]
#    2338 elif isinstance(node, (FusedSchedulerNode, SchedulerNode)):
# -> 2339     self.get_backend(device).codegen_nodes(node.get_nodes())  # type: ignore[possibly-undefined]
#    2340 else:
#    2341     assert isinstance(node, NopKernelSchedulerNode)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\codegen\cpp.py:3623, in CppScheduling.codegen_nodes(self, nodes)
#    3620 cpp_kernel_proxy = CppKernelProxy(kernel_group)
#    3621 cpp_kernel_proxy.codegen_nodes(nodes)
# -> 3623 kernel_group.finalize_kernel(cpp_kernel_proxy, nodes)
#    3625 args_num = self._get_scheduled_num_args()
#    3626 if args_num > CppScheduling.MAX_FUSED_KERNEL_ARGS_NUM:
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\codegen\cpp.py:3661, in KernelGroup.finalize_kernel(self, new_kernel, nodes)
#    3659 code = self.loops_code
#    3660 ws = self.ws
# -> 3661 new_kernel.codegen_loops(code, ws)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\codegen\cpp.py:3458, in CppKernelProxy.codegen_loops(self, code, worksharing)
#    3457 def codegen_loops(self, code, worksharing):
# -> 3458     self.codegen_loops_impl(self.loop_nest, code, worksharing)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\codegen\cpp.py:1832, in CppKernel.codegen_loops_impl(self, loop_nest, code, worksharing)
#    1830 stack.enter_context(code.indent())
#    1831 if loop_nest.root:
# -> 1832     gen_loops(loop_nest.root)
#    1833 else:
#    1834     gen_kernel(loop_nest.kernel)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\codegen\cpp.py:1804, in CppKernel.codegen_loops_impl.<locals>.gen_loops(loops, in_reduction)
#    1801         worksharing.parallel(threads)
#    1803 for loop in loops:
# -> 1804     gen_loop(loop, in_reduction)
#    1806 if loops:
#    1807     loop = loops[0]
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\codegen\cpp.py:1817, in CppKernel.codegen_loops_impl.<locals>.gen_loop(loop, in_reduction)
#    1815 def gen_loop(loop: LoopLevel, in_reduction=False):
#    1816     with contextlib.ExitStack() as stack:
# -> 1817         loop_lines = loop.lines()
#    1818         if loop_lines is None:
#    1819             return
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\codegen\cpp.py:3922, in LoopLevel.lines(self)
#    3920 elif self.simd_omp:
#    3921     line1 = f"#pragma omp {simd}{reduction}"
# -> 3922 elif not self.reduction_var_map and codecache.is_gcc():
#    3923     line1 = "#pragma GCC ivdep"
#    3924 else:
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\codecache.py:1001, in is_gcc()
#    1000 def is_gcc() -> bool:
# -> 1001     return bool(re.search(r"(gcc|g\+\+)", cpp_compiler()))
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\codecache.py:944, in cpp_compiler()
#     942 else:
#     943     search = (config.cpp.cxx,)
# --> 944 return cpp_compiler_search(search)
#
# File c:\Users\10199\Python\3.11\Lib\site-packages\torch\_inductor\codecache.py:971, in cpp_compiler_search(search)
#     969     except (subprocess.SubprocessError, FileNotFoundError, ImportError):
#     970         continue
# --> 971 raise exc.InvalidCxxCompiler()
#
# BackendCompilerFailed: backend='inductor' raised:
# InvalidCxxCompiler: No working C++ compiler found in torch._inductor.config.cpp.cxx: (None, 'g++')
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True
